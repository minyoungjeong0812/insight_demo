# %%
import pandas as pd

# %%
df1=pd.read_csv("export_dataframe1.csv")

# %%
df2=pd.read_csv("export_dataframe2.csv")

# %%
df3=pd.read_csv("export_dataframe3.csv")

# %%
df1
# Out:
#                          date gametype  headshot     playtime      title  \
# 0   Tue, Jun 2, 2020 10:00 AM    Squad         0   605.419983    Z-YiQiu
# 1    Tue, Jun 2, 2020 9:54 AM    Squad         0   214.776993    Z-YiQiu
# 2    Tue, Jun 2, 2020 9:38 AM    Squad         1   891.559021    Z-YiQiu
# 3    Tue, Jun 2, 2020 9:01 AM    Squad         2  1901.885000    Z-YiQiu
# 4    Tue, Jun 2, 2020 8:54 AM    Squad         0   278.175995    Z-YiQiu
# ..                        ...      ...       ...          ...        ...
# 95  Wed, Jun 3, 2020 10:55 AM    Squad         0   915.226013  Sherman-1
# 96  Wed, Jun 3, 2020 10:47 AM    Squad         0   358.355988  Sherman-1
# 97  Wed, Jun 3, 2020 10:15 AM    Squad         1  1643.412964  Sherman-1
# 98   Wed, Jun 3, 2020 9:57 AM    Squad         0   916.877014  Sherman-1
# 99   Wed, Jun 3, 2020 9:40 AM    Squad         0   874.763001  Sherman-1
#
#     kill  damage  distance  walking distance  ride distance  DBNO  Assists  \
# ...

# %%
df1=df1.rename(columns={"date":"playdate","walking distance" : "walking_distance","ride distance":"ride_distance","Assists":"assists"})

# %%
df1
# Out:
#                      playdate gametype  headshot     playtime      title  \
# 0   Tue, Jun 2, 2020 10:00 AM    Squad         0   605.419983    Z-YiQiu
# 1    Tue, Jun 2, 2020 9:54 AM    Squad         0   214.776993    Z-YiQiu
# 2    Tue, Jun 2, 2020 9:38 AM    Squad         1   891.559021    Z-YiQiu
# 3    Tue, Jun 2, 2020 9:01 AM    Squad         2  1901.885000    Z-YiQiu
# 4    Tue, Jun 2, 2020 8:54 AM    Squad         0   278.175995    Z-YiQiu
# ..                        ...      ...       ...          ...        ...
# 95  Wed, Jun 3, 2020 10:55 AM    Squad         0   915.226013  Sherman-1
# 96  Wed, Jun 3, 2020 10:47 AM    Squad         0   358.355988  Sherman-1
# 97  Wed, Jun 3, 2020 10:15 AM    Squad         1  1643.412964  Sherman-1
# 98   Wed, Jun 3, 2020 9:57 AM    Squad         0   916.877014  Sherman-1
# 99   Wed, Jun 3, 2020 9:40 AM    Squad         0   874.763001  Sherman-1
#
#     kill  damage  distance  walking_distance  ride_distance  DBNO  assists  \
# ...

# %%
df2=df2.rename(columns={"date":"playdate","walking distance" : "walking_distance","ride distance":"ride_distance","Assists":"assists"})

# %%
df3=df3.rename(columns={"date":"playdate","walking distance" : "walking_distance","ride distance":"ride_distance"})

# %%
df3
# Out:
#                       playdate gametype  headshot  playtime    title  kill  \
# 0    Thu, May 31, 2018 8:22 AM    Squad         0  1418.294  Ju_won2     1
# 1    Thu, May 31, 2018 7:49 AM    Squad         0   216.857  Ju_won2     1
# 2    Thu, May 31, 2018 7:20 AM    Squad         0   289.691  Ju_won2     0
# 3    Thu, May 31, 2018 6:45 AM    Squad         0  1315.789  Ju_won2     4
# 4    Thu, May 31, 2018 6:11 AM    Squad         0  1028.751  Ju_won2     0
# 5    Tue, May 29, 2018 1:56 AM    Squad         1  1404.679  Ju_won2     5
# 6    Tue, May 29, 2018 1:10 AM    Squad         0   888.724  Ju_won2     4
# 7    Mon, May 28, 2018 9:02 PM    Squad         6  1803.991  Ju_won2    12
# 8    Mon, May 28, 2018 8:29 PM    Squad         0   162.048  Ju_won2     0
# 9    Mon, May 28, 2018 7:54 PM    Squad         2  1954.506  Ju_won2     9
# 10   Mon, May 28, 2018 7:25 PM    Squad         2  1513.090  Ju_won2     6
# ...

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams["axes.labelsize"] = 20

# %%
g=sns.pairplot(df1)
for i, j in zip(*np.triu_indices_from(g.axes, 1)):
    g.axes[i, j].set_visible(False)

# %%
g=sns.pairplot(df2)
for i, j in zip(*np.triu_indices_from(g.axes, 1)):
    g.axes[i, j].set_visible(False)

# %%
g=sns.pairplot(df3)
for i, j in zip(*np.triu_indices_from(g.axes, 1)):
    g.axes[i, j].set_visible(False)

# %%
df1['kill_per_min']=(df1['kill']/df1['playtime'])*60

# %%
df1
# Out:
#                      playdate gametype  headshot     playtime      title  \
# 0   Tue, Jun 2, 2020 10:00 AM    Squad         0   605.419983    Z-YiQiu
# 1    Tue, Jun 2, 2020 9:54 AM    Squad         0   214.776993    Z-YiQiu
# 2    Tue, Jun 2, 2020 9:38 AM    Squad         1   891.559021    Z-YiQiu
# 3    Tue, Jun 2, 2020 9:01 AM    Squad         2  1901.885000    Z-YiQiu
# 4    Tue, Jun 2, 2020 8:54 AM    Squad         0   278.175995    Z-YiQiu
# ..                        ...      ...       ...          ...        ...
# 95  Wed, Jun 3, 2020 10:55 AM    Squad         0   915.226013  Sherman-1
# 96  Wed, Jun 3, 2020 10:47 AM    Squad         0   358.355988  Sherman-1
# 97  Wed, Jun 3, 2020 10:15 AM    Squad         1  1643.412964  Sherman-1
# 98   Wed, Jun 3, 2020 9:57 AM    Squad         0   916.877014  Sherman-1
# 99   Wed, Jun 3, 2020 9:40 AM    Squad         0   874.763001  Sherman-1
#
#     kill  damage  distance  walking_distance  ride_distance  DBNO  assists  \
# ...

# %%
df2['kill_per_min']=(df2['kill']/df2['playtime'])*60

# %%
df3['kill_per_min']=(df3['kill']/df3['playtime'])*60

# %%
df2
# Out:
#                       playdate    gametype  headshot     playtime  \
# 0     Mon, Jun 1, 2020 2:21 AM  Ranked FPP         2  1384.744019
# 1     Mon, Jun 1, 2020 2:02 AM  Ranked FPP         1  1063.515015
# 2     Mon, Jun 1, 2020 1:50 AM  Ranked FPP         3   552.127991
# 3     Mon, Jun 1, 2020 1:30 AM  Ranked FPP         1  1069.984985
# 4    Thu, May 14, 2020 2:10 AM       Squad         0  1115.458008
# 5    Thu, May 14, 2020 2:03 AM       Squad         0   263.278015
# 6    Thu, May 14, 2020 1:31 AM       Squad         0  1768.020020
# 7    Thu, May 14, 2020 1:00 AM       Squad         2  1764.614014
# 8   Thu, May 14, 2020 12:50 AM       Squad         0   264.009003
# 9   Thu, May 14, 2020 12:22 AM       Squad         0  1574.631958
# 10  Thu, May 14, 2020 12:18 AM       Squad         0   170.455994
# 11  Wed, May 13, 2020 11:56 PM       Squad         2  1186.836060
# 12   Wed, May 13, 2020 2:13 PM       Squad         4  1345.595947
# ...

# %%
df3
# Out:
#                       playdate gametype  headshot  playtime    title  kill  \
# 0    Thu, May 31, 2018 8:22 AM    Squad         0  1418.294  Ju_won2     1
# 1    Thu, May 31, 2018 7:49 AM    Squad         0   216.857  Ju_won2     1
# 2    Thu, May 31, 2018 7:20 AM    Squad         0   289.691  Ju_won2     0
# 3    Thu, May 31, 2018 6:45 AM    Squad         0  1315.789  Ju_won2     4
# 4    Thu, May 31, 2018 6:11 AM    Squad         0  1028.751  Ju_won2     0
# 5    Tue, May 29, 2018 1:56 AM    Squad         1  1404.679  Ju_won2     5
# 6    Tue, May 29, 2018 1:10 AM    Squad         0   888.724  Ju_won2     4
# 7    Mon, May 28, 2018 9:02 PM    Squad         6  1803.991  Ju_won2    12
# 8    Mon, May 28, 2018 8:29 PM    Squad         0   162.048  Ju_won2     0
# 9    Mon, May 28, 2018 7:54 PM    Squad         2  1954.506  Ju_won2     9
# 10   Mon, May 28, 2018 7:25 PM    Squad         2  1513.090  Ju_won2     6
# ...

# %%
kpm_1=df1["kill_per_min"]

# %%
kpm_2=df2["kill_per_min"]
kpm_3=df3["kill_per_min"]

# %%
kpm_1
# Out:
# 0     0.000000
# 1     0.000000
# 2     0.201894
# 3     0.094643
# 4     0.215691
#         ...
# 95    0.131115
# 96    0.167431
# 97    0.219056
# 98    0.065440
# 99    0.000000
# Name: kill_per_min, Length: 100, dtype: float64

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set(font_scale = 1.7)
sns.distplot(kpm_1, label='regular')
sns.distplot(kpm_2, label='cheater')
sns.distplot(kpm_3, label = 'pro')
plt.legend()

# %%
df1['head_per_kill'] = df1['headshot']/df1['kill']
df2['head_per_kill'] = df2['headshot']/df2['kill']
df3['head_per_kill'] = df3['headshot']/df3['kill']

# %%
df1['head_per_kill']=df1['head_per_kill'].fillna(0)

# %%
df2['head_per_kill']=df2['head_per_kill'].fillna(0)
df3['head_per_kill']=df3['head_per_kill'].fillna(0)

# %%
hpk_1=df1["head_per_kill"]
hpk_2=df2["head_per_kill"]
hpk_3=df3["head_per_kill"]

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set(font_scale = 1.7)
sns.distplot(hpk_1, kde='False',label='regular')
sns.distplot(hpk_2, kde='False',label='cheater')
sns.distplot(hpk_3, label = 'pro',kde='False')
plt.legend()

# %%
df1['playdate']=pd.to_datetime(df1['playdate'], infer_datetime_format=True)

# %%
df2['playdate']=pd.to_datetime(df2['playdate'], infer_datetime_format=True)
df3['playdate']=pd.to_datetime(df3['playdate'], infer_datetime_format=True)

# %%
df2
# Out:
#               playdate    gametype  headshot     playtime         title  kill  \
# 0  2020-06-01 02:21:00  Ranked FPP         2  1384.744019  baby-thor_10    11
# 1  2020-06-01 02:02:00  Ranked FPP         1  1063.515015  baby-thor_10     3
# 2  2020-06-01 01:50:00  Ranked FPP         3   552.127991  baby-thor_10     6
# 3  2020-06-01 01:30:00  Ranked FPP         1  1069.984985  baby-thor_10     2
# 4  2020-05-14 02:10:00       Squad         0  1115.458008  baby-thor_10     7
# 5  2020-05-14 02:03:00       Squad         0   263.278015  baby-thor_10     2
# 6  2020-05-14 01:31:00       Squad         0  1768.020020  baby-thor_10    13
# 7  2020-05-14 01:00:00       Squad         2  1764.614014  baby-thor_10    13
# 8  2020-05-14 00:50:00       Squad         0   264.009003  baby-thor_10     3
# 9  2020-05-14 00:22:00       Squad         0  1574.631958  baby-thor_10     1
# 10 2020-05-14 00:18:00       Squad         0   170.455994  baby-thor_10     0
# ...

# %%
df3
# Out:
#               playdate gametype  headshot  playtime    title  kill damage  \
# 0  2018-05-31 08:22:00    Squad         0  1418.294  Ju_won2     1    559
# 1  2018-05-31 07:49:00    Squad         0   216.857  Ju_won2     1    186
# 2  2018-05-31 07:20:00    Squad         0   289.691  Ju_won2     0      0
# 3  2018-05-31 06:45:00    Squad         0  1315.789  Ju_won2     4    343
# 4  2018-05-31 06:11:00    Squad         0  1028.751  Ju_won2     0    175
# 5  2018-05-29 01:56:00    Squad         1  1404.679  Ju_won2     5    763
# 6  2018-05-29 01:10:00    Squad         0   888.724  Ju_won2     4    308
# 7  2018-05-28 21:02:00    Squad         6  1803.991  Ju_won2    12  1,612
# 8  2018-05-28 20:29:00    Squad         0   162.048  Ju_won2     0     32
# 9  2018-05-28 19:54:00    Squad         2  1954.506  Ju_won2     9  1,128
# 10 2018-05-28 19:25:00    Squad         2  1513.090  Ju_won2     6    891
# 11 2018-05-28 18:51:00    Squad         1   148.107  Ju_won2     2    329
# ...

# %%
df1
# Out:
#               playdate gametype  headshot     playtime      title  kill  \
# 0  2020-06-02 10:00:00    Squad         0   605.419983    Z-YiQiu     0
# 1  2020-06-02 09:54:00    Squad         0   214.776993    Z-YiQiu     0
# 2  2020-06-02 09:38:00    Squad         1   891.559021    Z-YiQiu     3
# 3  2020-06-02 09:01:00    Squad         2  1901.885000    Z-YiQiu     3
# 4  2020-06-02 08:54:00    Squad         0   278.175995    Z-YiQiu     1
# ..                 ...      ...       ...          ...        ...   ...
# 95 2020-06-03 10:55:00    Squad         0   915.226013  Sherman-1     2
# 96 2020-06-03 10:47:00    Squad         0   358.355988  Sherman-1     1
# 97 2020-06-03 10:15:00    Squad         1  1643.412964  Sherman-1     6
# 98 2020-06-03 09:57:00    Squad         0   916.877014  Sherman-1     1
# 99 2020-06-03 09:40:00    Squad         0   874.763001  Sherman-1     0
#
#     damage  distance  walking_distance  ride_distance  DBNO  assists  heal  \
# ...

# %%
df1=df1.sort_values(by=['playdate'])
df2=df2.sort_values(by=['playdate'])
df3=df3.sort_values(by=['playdate'])

# %%
df1.to_csv('df1.csv', index=False)
df2.to_csv('df2.csv', index=False)
df3.to_csv('df3.csv', index=False)

# %%
##Index set

# %%
df1_ind=df1
df2_ind=df2
df3_ind=df3

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

df1_ind.set_index(['playdate'],inplace=True)
ax = sns.scatterplot(df1_ind.index,df1_ind["kill"],data=df1_ind)
ax.set_xlim(df1_ind.index[0], df1_ind.index[-1])
# Out:
# (737574.75, 737579.88125)

# %%
sns.set(rc={'figure.figsize':(15,8.27)})

df2_ind.set_index(['playdate'],inplace=True)
ax = sns.scatterplot(df2_ind.index,df2_ind["kill"],data=df2_ind)
ax.set_xlim(df2_ind.index[0], df2_ind.index[-1])
# Out:
# (737558.5729166666, 737577.0979166667)

# %%
sns.set(rc={'figure.figsize':(15,8.27)})

df3_ind.set_index(['playdate'],inplace=True)
ax = sns.scatterplot(df3_ind.index,df3_ind["kill"],data=df3_ind)
ax.set_xlim(df3_ind.index[0], df3_ind.index[-1])
# Out:
# (736841.4381944444, 736845.348611111)

# %%
df2
# Out:
#                        gametype  headshot     playtime         title  kill  \
# playdate
# 2020-05-13 13:45:00       Squad         5  1228.647949  baby-thor_10     9
# 2020-05-13 14:10:00       Squad         0    72.561996  baby-thor_10     0
# 2020-05-13 14:13:00       Squad         4  1345.595947  baby-thor_10    11
# 2020-05-13 23:56:00       Squad         2  1186.836060  baby-thor_10    11
# 2020-05-14 00:18:00       Squad         0   170.455994  baby-thor_10     0
# 2020-05-14 00:22:00       Squad         0  1574.631958  baby-thor_10     1
# 2020-05-14 00:50:00       Squad         0   264.009003  baby-thor_10     3
# 2020-05-14 01:00:00       Squad         2  1764.614014  baby-thor_10    13
# 2020-05-14 01:31:00       Squad         0  1768.020020  baby-thor_10    13
# 2020-05-14 02:03:00       Squad         0   263.278015  baby-thor_10     2
# 2020-05-14 02:10:00       Squad         0  1115.458008  baby-thor_10     7
# ...
